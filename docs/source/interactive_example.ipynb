# %% [markdown]
# # Interactive Python
# ## Example with Jupiter Notebook
# This is an example how to use Jupiter Notebooks for Sphinx documentation.

# %% [markdown]
# Hello World example:

# %%
print("Hello World of Documentation!")

# %% [markdown]
# This code works, feel free to expand your documentation with more code.
